# %% [markdown]
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

data = pd.read_csv('data.csv')

print(data.head())
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
data.isnull().sum()
# Out:
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0              2.0  30.0  Female    39.0             14.0            5.0
# 1              3.0  65.0  Female    49.0              1.0           10.0
# 2              4.0  55.0  Female    14.0              4.0            6.0
# 3              5.0  58.0    Male    38.0             21.0            7.0
# 4              6.0  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 440828    449995.0  42.0    Male    54.0             15.0            1.0
# 440829    449996.0  25.0  Female     8.0             13.0            1.0
# 440830    449997.0  26.0    Male    35.0             27.0            1.0
# 440831    449998.0  28.0    Male    55.0             14.0            2.0
# 440832    449999.0  31.0    Male    48.0             20.0            1.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data.hist(bins=50,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'CustomerID'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Tenure'}>],
#        [<Axes: title={'center': 'Usage Frequency'}>,
#         <Axes: title={'center': 'Support Calls'}>,
#         <Axes: title={'center': 'Payment Delay'}>],
#        [<Axes: title={'center': 'Total Spend'}>,
#         <Axes: title={'center': 'Last Interaction'}>,
#         <Axes: title={'center': 'Churn'}>]], dtype=object)

# %%
ages = data['Age'].dropna() 
plt.figure(figsize=(10, 6))
plt.hist(ages, bins=20, edgecolor='black', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages in the Population')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(gender_counts.index, gender_counts.values, color=['black', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Genders in the Population')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data = pd.DataFrame(np.random.rand(10, 10))

plt.figure(figsize=(10, 8))
sns.heatmap(data, annot=True, cmap='plasma', cbar=True)
plt.title('Heatmap')
plt.show()

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [25, 35, 20, 20]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart')
plt.axis('equal')  
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [20, 35, 30, 25]
plt.figure(figsize=(8, 6))
plt.bar(categories, values, color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Vertical Bar Chart')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.barh(categories, values, color='lightgreen')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Chart')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
men_means = [20, 35, 30, 35]
women_means = [25, 32, 34, 20]
width = 0.35  
fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(categories))
bar1 = ax.bar(x - width/2, men_means, width, label='Men', color='lightblue')
bar2 = ax.bar(x + width/2, women_means, width, label='Women', color='lightcoral')
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Grouped Bar Chart')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
bars1 = [20, 35, 30, 35]
bars2 = [25, 32, 34, 20]
plt.figure(figsize=(10, 6))
plt.bar(categories, bars1, color='lightblue', label='Bars1')
plt.bar(categories, bars2, bottom=bars1, color='lightcoral', label='Bars2')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Chart')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
start = [10, 15, 20, 25]
end = [30, 35, 40, 45]
plt.figure(figsize=(10, 6))
plt.barh(categories, width=end, left=start, color='green')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Floating Bar Chart')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
means = [20, 35, 30, 25]
errors = [2, 3, 4, 1]
plt.figure(figsize=(8, 6))
plt.bar(categories, means, yerr=errors, capsize=5, color='blue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Error Bar Chart')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
np.random.seed(0)
ages = np.random.randint(18, 80, size=1000)  
plt.figure(figsize=(10, 6))
plt.hist(ages, bins=20, edgecolor='red', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
